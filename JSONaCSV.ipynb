# %% [markdown]
# # Lectores

# %%
import pandas as pd

# %%
# Using Pandas, read JSON and save it to CSV
namefile = 'Sevilla-aeropuerto-2021.json'
df = pd.read_json(namefile)
df.to_csv('prueba.csv')

# %%
df
# Out:
#      altitud   dir       fecha horaPresMax horaPresMin horaracha horatmax  \
# 0         34  99.0  2021-01-01      Varias          17    Varias    14:19
# 1         34  27.0  2021-01-02      Varias          00     14:06    15:12
# 2         34  99.0  2021-01-03          11          17    Varias    15:15
# 3         34  22.0  2021-01-04          00          24     17:26   Varias
# 4         34   5.0  2021-01-05      Varias          17    Varias    12:58
# 5         34   7.0  2021-01-06      Varias          24     17:25    14:05
# 6         34  99.0  2021-01-07      Varias          05    Varias   Varias
# 7         34   4.0  2021-01-08          00          17     10:36   Varias
# 8         34  25.0  2021-01-09      Varias          00     14:48    14:34
# 9         34   5.0  2021-01-10      Varias          00     13:13    15:34
# 10        34  99.0  2021-01-11      Varias          00    Varias    15:58
# 11        34   5.0  2021-01-12      Varias          00     10:24    15:23
# ...

# %%
selected = df[["fecha", "tmin", "horatmin", "tmax", "horatmax"]] # seleccionamos las columnas deseadas

# %%
selected.head() # Visualizar lo que tenemos
# Out:
#         fecha  tmin horatmin  tmax horatmax
# 0  2021-01-01   4,7    23:52  13,6    14:19
# 1  2021-01-02   0,2    07:34  12,8    15:12
# 2  2021-01-03  -1,5    06:16  12,5    15:15
# 3  2021-01-04  -0,6    07:10  12,3   Varias
# 4  2021-01-05   3,6    08:19  11,3    12:58

# %%
saved_name = namefile.replace("json", "csv")

selected.to_csv(saved_name)
